# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import glob
import os
import peakutils
import logging
import datetime
import warnings
import sys
from lmfit.models import PseudoVoigtModel, GaussianModel
#from jupyterthemes import jtplot 
from matplotlib.colors import Normalize

# %%
sys.path.append('C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\scripts')

# %%
from xps.xps_sw import *
from xps.xps_import import *
from xps.xps_analysis import *
from xps.xps_bg import *
from xps.xps_fits import *

#jtplot.style('grade3', context='talk', grid=False, ticks=True, fscale=1.5)
logging.getLogger().setLevel(logging.CRITICAL)
warnings.filterwarnings("ignore")

# %% [markdown]
# Atomic sensibility factor : asf -> para normalizar

# %%
asf = dict({'C1s' : 0.296, 'O1s' : 0.711, 'O1s_sub' : 0.711, 'N1s' : 0.477, 'Ba3d' : 7.49, 'Ba_3d_5/2' : 7.49, 'Ba_3d_3/2' : 5.20,
            'Br_3p' : 1.054, 'Cu_2p' : 5.321, 'Ba_4d': 2.35, 'Na1s' : 1.685, 'Cl_2s' : 0.37, 'Ru3d' : 4.273,
           'In3d' : 4.359, 'Sn3d' : 4.725, 'Cl2p' : 0.891, 'Cl2p_(2)' : 0.891, 'Cl2p_(3)' : 0.891, 'Si2p': 0.339})

asf2 = {'Ba_3d_5/2' : 25.8, 'Ba_3d_3/2': 17.9, 'Ba_4d': 5.86, 'Cl_2p': 2.28, 'Cl_2s': 1.69, }

asf3 = {'Ba_3d_5/2' : 64.3, 'Ba_3d_3/2': 49.9, 'Ba_4d': 5.86, 'Cl_2p': 2.28, 'Cl_2s': 1.50}
mfps = {'Cu2p' : 1.86, 'In3d': 3.05, 'Si2p': 3.8}

# %%
regss = ['O1s', 'Si2p', 'N1s', 'C1s', 'In3d', 'Ba3d5/2', 'Cl2p', 'Ru3d5/2', 'Si2s']
asfScof = {}
for r in regss:
    asfScof.update(search_asf(r))

# %% [markdown]
# # Import data

# %%
filehd = 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\20220831_ITO_G2SL_BOLD128_A2_48h.xy'

xpsov = xps_data_import(filehd)

# %%
plt.figure(figsize=(14,8))
plot_region(xpsov, 'overview')

# %% [markdown]
# En ITO, los elementos que han de aparecer son Carbono, Nitrogeno, Oxígeneo, y Silicio
#
# Con BaCl2, tenemos que tener tb Ba3d, Cl2p y shift en el oxígeno

# %%
xpsov.dfx
# Out:
# range           overview           C1s            N1s            Si2p  \
# properties        energy counts energy  counts energy   counts energy
# 0           1.200000e+03   9395  295.0  972.50  409.0  1047.20  107.0
# 1           1.199000e+03   9385  294.9  959.25  408.9  1034.10  106.9
# 2           1.198000e+03   9715  294.8  952.25  408.8  1042.60  106.8
# 3           1.197000e+03   9185  294.7  966.25  408.7  1035.10  106.7
# 4           1.196000e+03   9475  294.6  951.75  408.6  1071.55  106.6
# ...                  ...    ...    ...     ...    ...      ...    ...
# 1200       -2.273737e-13    745    NaN     NaN    NaN      NaN    NaN
# 1201       -1.000000e+00    520    NaN     NaN    NaN      NaN    NaN
# 1202       -2.000000e+00    645    NaN     NaN    NaN      NaN    NaN
# 1203       -3.000000e+00    605    NaN     NaN    NaN      NaN    NaN
# 1204       -4.000000e+00    640    NaN     NaN    NaN      NaN    NaN
#
# ...

# %% [markdown]
# ## Data G2-SL sublimated on ITO ?????

# %%
path = 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\'
files = glob.glob(path+'/**/*.sxy') #Pablo: xps_spectra/ITO_G2SL/ es lo mismo???
files.sort()
files = files[::-1]
files
# Out:
# ['C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\20220922_ITO_clean3_AYN10.sxy',
#  'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\ 20220831_ITO_G2SL_BOLD128_A2_48h_BaCl2_1min.sxy',
#  'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\ 20220831_ITO_G2SL_BOLD128_A2_48h.sxy']

# %%
g2sl = [read_processed_xp(f) for f in files]
g2sl
# Out:
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\20220922_ITO_clean3_AYN10.sxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\ 20220831_ITO_G2SL_BOLD128_A2_48h_BaCl2_1min.sxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_31_ITO_G2SL_BOLD_128_A2_48h\\proc\\ 20220831_ITO_G2SL_BOLD128_A2_48h.sxy.ft', returning empty fit dict
# ...

# %% [markdown]
# ## Names and colors

# %%
[xp.name for xp in g2sl]
# Out:
# ['ITO_clean3_AYN10',
#  'ITO_G2SL_BOLD128_A2_48h_BaCl2_1min',
#  'ITO_G2SL_BOLD128_A2_48h']

# %%
names = ['ITO_clean3_AYN10','ITO_G2SL_BOLD128_A2_48h',  'ITO_G2SL_BOLD128_A2_48h_BaCl2_1min']
cols = ['b', 'g', 'r', 'y', 'm', 'c' ,'k', 'green']
for c, n, xp in zip (cols, names, g2sl):
    xp.color = c
    xp.name = n

# %% [markdown]
# # Plot regions G2

# %% [markdown]
# ## Ba/G2/ITO

# %%
#Plot con Bario
regs = ['Ba3d', 'Cl2p', 'O1s', 'In3d',  'N1s', 'C1s',] 
ax = plot_xp_regions(g2sl, regs, ncols=3);
ax[0,0].invert_xaxis()
ax[0,1].invert_xaxis()
# ax[1,0].invert_xaxis()

# %%
#Plot sin Bario
for xp in g2sl[3:]:
    plot_region(xp, 'In3d')
    #plot_region(xp, 'N1s')  
    plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

    plt.gca().invert_xaxis()

# %%
g2sl[0].dfx.columns.levels
# Out:
# FrozenList([['C1s', 'C1s_bg', 'In3d', 'In3d_bg', 'N1s', 'N1s_bg', 'O1s', 'O1s_bg', 'Si2p', 'Si2p_bg', 'Si2s', 'Si2s_bg', 'Sn3d', 'overview'], ['counts', 'energy']])

# %% [markdown]
# # Escalar y restar bg del ITO

# %% [markdown]
# Para compararlos tenemos que escalarlos, al prepocesarlos quitamos el bg y al ser en diferentes condiciones la intensidad no es la misma. Tienen que ser la diferencia entre .uxy (unscale) y .sxy (scale)

# %%
scaled = scale_and_plot_spectra(g2sl, region='In3d') #Esto se hace con los componentes del sustrato

# %%
[xp.name for xp in scaled]
# Out:
# ['10-ITO clean', '10-G2-SL 18h30m', '10-BaCl$_2$ 4min/G2-SL 18h30m']

# %%
for xp in scaled[:4]: 
    print(xp.name)
    plot_region(xp, 'N1s')
#plt.gca().invert_xaxis()
# Out:
# ITO_clean3_AYN10
# ITO_G2SL_BOLD128_A2_48h
# ITO_G2SL_BOLD128_A2_48h_BaCl2_1min

# %%
g2sl[0].dfx.columns.levels
# Out:
# FrozenList([['Ba3d', 'C1s', 'Cl2p', 'In3d', 'N1s', 'C1s_bg', 'N1s_bg', 'O1s_bg', 'In3d_bg', 'Ba3d_bg', 'Cl2p_bg'], ['counts', 'energy']])

# %%
compress_noisy_region(scaled[0], scaled[1], 'N1s', inplace=True); #quitar ruido para medidas que no estan claras
scaled[1].color = 'b'

# %%
for xp in scaled:
    try:
        plot_region(xp, 'O1s')
    except KeyError: pass
#plt.gca().invert_xaxis()

# %%
for xp in [scaled[1], scaled[3]]:
    try:
        plot_region(xp, 'Sn3d')
    except KeyError: pass
plt.gca().invert_xaxis()

# %%
[xp.name for xp in scaled]
# Out:
# ['10-ITO clean', '10-G2-SL 18h30m', '10-BaCl$_2$ 4min/G2-SL 18h30m']

# %%
for xp in scaled[1:]:
    trim_spectra(xp, scaled[0], region='O1s', inplace=True) 
#para comparar entre picos tiene que tener el mismo rango de forma automática
#scaled[0] es el pico con el que se compara

# %%
sub=[scaled[0]]
for xp in scaled[1:]:
    subscaled = subtract_ref_region(xp, scaled[0], region='O1s')
    sub.append(subscaled)

for xp in sub[1:]:
    crop_spectrum(xp, region='O1s_sub', edw=530.3, inplace=True)
#para comparar entre picos tiene que tener el mismo rango de forma manual

# %%
sub[1].color = 'g'
sub[2].color = 'r'

# %%
'O1s_sub'

# %%
for xp in sub[0:]:
    plot_region(xp, 'O1s')
plt.gca().set(title='$O_{ITO}$')
#plt.gca().invert_xaxis()
plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

# %%
for xp in sub[1:]:
    plot_region(xp, 'O1s_sub')
plt.gca().set(title='$O_{ITO}$ subtracted')
plt.gca().invert_xaxis()
plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

# %%
sub = region_bg_subtract(sub, 'O1s_sub') #Para que quede bien subtraemos el bg
# Out:
# KeyError in 'O1s_sub'

# %% [markdown]
# # Stoichiometry

# %% [markdown]
# ### Batch Integration (IMP)

# %%
asfScof['Ba3d'] = 5.8329

# %%
regs = ['C1s', 'O1s_sub', 'N1s', 'In3d', 'Ba3d', 'Cl2p']

for r in regs:
    integrateRegions(sub, r, asf)
#Tener en cuenta: 1 Fija intervalos para tener siempre la misma anchura
                 #2 Si no sale automatico utilizar indRef o sino espedificar eup (energia up) edw (energia down)
                 # Tener cuidado con los factores de sensibilidad
#Para poder el valor de las areas: experiments[3].area (todos los exp)
                                #experiments[3].area['O1s']
# Out:
# 'O1s_sub' region does not exist in ITO_clean3_AYN10
# 'Ba3d' region does not exist in ITO_clean3_AYN10
# 'Cl2p' region does not exist in ITO_clean3_AYN10

# %%
region = 'Si2p'

# %%
plot_region(sub[1], region)

# %%
integrateRegions(sub, region, asfScof)
# Out:
# 'Si2p' region does not exist in ITO_BOLD_131C1_3gota_BaCl2_3min
# [12.902927264199787,
#  15.791249999999208,
#  33.67088710633425,
#  12.902927264199787,
#  21.155272380052462,
#  93.49973316513851,
#  16.173293931864155]

# %% [markdown]
# ### Results

# %%
asfScof['N1s'], asfScof['Si2p']
# Out:
# (0.4063205417607223, 0.18442437923250563)

# %%
asf['N1s'] / asf['C1s']
# Out:
# 1.6114864864864864

# %%
a = {'C1s': 12+6+6+5+2+1+3, 'N1s': 4, 'Si2p': 1, 'O1s': 9, 'Ba3d': 1e-10, 'Cl2p': 1e-10, 'G2': 1, 'Na1s': 1e-10, 'Ru3p': 1e-10}
stog2 = XPS_experiment(name='Sto. G2-SL', area=a) #Valores para comparar con la referencia, #atomos (estequeometria)

# %%
a['C1s']
# Out:
# 35

# %%
num = ['C1s', 'O1s', 'C1s']
denom = ['O1s', 'N1s','N1s']
display_stoichiometry(sub+[stog2], num, denom)
# Out:
# C1s  or  O1s  was not measured
# O1s  or  N1s  was not measured
# C1s  or  O1s  was not measured
# O1s  or  N1s  was not measured
# C1s  or  O1s  was not measured
# O1s  or  N1s  was not measured
# <table><tr><td><h4>Experiment</h4><td><td><h4>C1/O1</h4><td><td><h4>O1/N1</h4><td><td><h4>C1/N1</h4><td></tr><tr><td><h4>ITO_clean3_AYN10</h4><td><td><h4>21.83</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h</h4><td><td><h4>17.25</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h_BaCl2_1min</h4><td><td><h4>23.58</h4><td></tr><tr><td><h4>Sto. G2-SL</h4><td><td><h4>3.89</h4><td><td><h4>2.25</h4><td><td><h4>8.75</h4><td></tr></table>

# %%
make_stoichometry_table(sub+[stog2], num, denom)#Con esto se puede exportar a latex
# Out:
# Experiment\tC1/O1\tO1/N1\tC1/N1\tSi2/N1\tSi2/C1\t
# ITO_BOLD_131C1_3gota_100grad\t-1.14 \t -6.59 \t 7.49 \t 0.13 \t 0.02 \t
# ITO_BOLD_131B1_2gota_100grad\t1.78 \t 5.88 \t 10.49 \t 0.12 \t 0.01 \t
# ITO_BOLD_131B1_2gotas_BaCl2_1min\t3.21 \t 20.77 \t 66.68 \t 1.71 \t 0.03 \t
# ITO_BOLD_131C1_3gota_100grad\t-2.89 \t -2.59 \t 7.49 \t 0.13 \t 0.02 \t
# ITO_BOLD_131C1_3gota_100grad_air_anneal\tinf \t 0.00 \t 6.60 \t 0.14 \t 0.02 \t
# ITO_BOLD_131C1_3gota_BaCl2_3min\t-7.30 \t -0.95 \t 6.92 \t 0.00 \t 0.00 \t
# ITO_BOLD_132B1_90grad\t1.43 \t 8.45 \t 12.07 \t 0.63 \t 0.05 \t
# ITO_BOLD_132B1_90grad_BaCl2_3min\t3.17 \t 3.06 \t 9.69 \t 0.12 \t 0.01 \t
# Sto. G2-SL\t3.89 \t 2.25 \t 8.75 \t 0.25 \t 0.03 \t

# %%
for xp in sub:
    xp.area['G2'] = xp.area['N1s'] / 4
#     xp.area['G2'] = xp.area['C1s'] / 35 
#Para comparar cuanto Bario hay por molecula 
#y por eso se divide por el numero de nitrogeno,...

# %%
for xp in sub:
#     xp.area['G2'] = xp.area['N1s'] / 4
    xp.area['G2'] = xp.area['C1s'] / 35

# %%
num = ['Ba3d', 'Cl2p']
denom = ['G2','Ba3d']
display_stoichiometry(sub, num, denom)
# Out:
# <table><tr><td><h4>Experiment</h4><td><td><h4>Ba3/G</h4><td><td><h4>Cl2/Ba3</h4><td></tr><tr><td><h4>ITO_clean3_AYN10</h4><td><td><h4>0.00</h4><td><td><h4>1.00</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h</h4><td><td><h4>13.78</h4><td><td><h4>0.93</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h_BaCl2_1min</h4><td><td><h4>3.49</h4><td><td><h4>3.36</h4><td></tr></table>

# %%
num = ['Ba3d']
denom = ['G2']
display_stoichiometry(sub, num, denom)
# Out:
# <table><tr><td><h4>Experiment</h4><td><td><h4>Ba3/G</h4><td></tr><tr><td><h4>ITO_clean3_AYN10</h4><td><td><h4>0.00</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h</h4><td><td><h4>13.78</h4><td></tr><tr><td><h4>ITO_G2SL_BOLD128_A2_48h_BaCl2_1min</h4><td><td><h4>3.49</h4><td></tr></table>

# %% [markdown]
# # Coverage

# %%
path = 'C://Users//USUARIO//Desktop//Adelina//xps_sw-master//data//ITO_G2SL_copy/2022_09_22_ITO_AYN_10/'
files = glob.glob(path+'/**/*.uxy')
files.sort()
files = files[::-1]
#Volvemos a importar datos pq al escalar perdemos la informacion del coverage
#El coverage se saca por la diferencia de alturas
unscaled = [read_processed_xp(f) for f in files]
# Out:
# [Errno 2] No such file or directory: 'C://Users//USUARIO//Desktop//Adelina//xps_sw-master//data//ITO_G2SL_copy/2022_09_22_ITO_AYN_10\\proc\\ 20220922_ITO_clean3_AYN10.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C://Users//USUARIO//Desktop//Adelina//xps_sw-master//data//ITO_G2SL_copy/2022_09_22_ITO_AYN_10\\proc\\ 20220922_ITO_AYN10_G2SL_subl_18h30min.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C://Users//USUARIO//Desktop//Adelina//xps_sw-master//data//ITO_G2SL_copy/2022_09_22_ITO_AYN_10\\proc\\ 20220922_ITO_AYN10_G2SL_subl_18h30m_BaCl2_4min.uxy.ft', returning empty fit dict

# %%
file = 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_09_14_AYN_09\\proc\\20220914_ITO_clean_AYN09.uxy'
clean = read_processed_xp(file)
unscaled.append(clean)
# Out:
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_09_14_AYN_09\\proc\\20220914_ITO_clean_AYN09.uxy.ft', returning empty fit dict

# %%
for i, xp in enumerate(unscaled):
    print(i, xp.name)
# Out:
# 0 ITO_clean3_AYN10
# 1 ITO_AYN10_G2SL_subl_18h30min
# 2 ITO_AYN10_G2SL_subl_18h30m_BaCl2_4min

# %%
region = 'In3d' #plot para comprobar que hay diferencia -> el clean tiene que ser el más alto sino descartar datos
for xp in unscaled:
    plot_region(xp, region)
    plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

# %%
#IMP
inds = [[1, 2,0]] #Tomamos los datos de 2 en 2 y comparamos entre estos
     #=[2, 3, 4, 5, 6, 7] compara todos con el ultimo que es el clean
arrange_coverages(unscaled, inds, r_ml=1.1,
                  region='In3d', mfp=3.05, takeoff=10)
#Depende de: 1 que muestra estás comparando con que sustrato
            #2 que estemos cogiendo bien el clean
            #3 Calcula primero el grosor y luego calcula ese grosor a cuantas capas corresponde
#r_ml radio molecula (NO TOCAR), takeoff el agulo de la muestra (NO TOCAR), 
#mfp 'mean free path' determina cuanto hay de grosor (NO TOCAR)

#Para obtener por separado el resultado: experiments[3].area['layers'] -> Error: dlayers
# Out:
# matrix([[0.40932074, 0.00228458],
#         [0.64978816, 0.00371188]])

# %%
# xp de referencia incorrecto si sale negativo

# %%
plot_coverages(unscaled)
# Out:
# <AxesSubplot:xlabel='Layers'>

# %% [markdown]
# # Fits

# %% [markdown]
# ## Carbono

# %%
path = 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\'
files = glob.glob(path+'/**/*.uxy') #Pablo: xps_spectra/ITO_G2SL/ es lo mismo???
files.sort()
files
# Out:
# ['C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220825_ITO_G2SL_AYN05_clean.uxy',
#  'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220825_ITO_G2SL_AYN05_subl_2h.uxy',
#  'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220826_ITO_G2SL_AYN05_subl_2h_Ba_2min.uxy']

# %%
bg = [read_processed_xp(f) for f in files]
# Out:
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220825_ITO_G2SL_AYN05_clean.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220825_ITO_G2SL_AYN05_subl_2h.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: 'C:\\Users\\USUARIO\\Desktop\\Adelina\\xps_sw-master\\data\\ITO_G2SL\\2022_08_25_ITO_G2SL_subl2h_AYN_05\\proc\\20220826_ITO_G2SL_AYN05_subl_2h_Ba_2min.uxy.ft', returning empty fit dict

# %%
reg = 'C1s'
for i, xp in enumerate(bg[1:]):
    xf = XPFit(xp, reg)
    xf.voigt()
    plot_fit_result(xp, reg, offset =6*i)
plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

# %%
reg = 'C1s'
bg[1]
xf = XPFit(xp, reg)
xf.double_voigt(287)
plot_fit_result(xp, reg)
plt.gca().set(xlim =(295,280))
plt.legend(bbox_to_anchor=(1.05, 0), loc=3, borderaxespad=0)

# %%
#Forma manual a lo bruto
reg = 'C1s'
xp = bg[1]

pars = [100, 286, 1] #parámetros [(altura), (centro), (ancho)]
bounds = [(10,15), (287, 290), (1.2,0.9)] #limites de los parámetros [(altura), (centro), (ancho)]
xf = XPFit(xp, reg)
xpfit = xf.voigt()

xf.add_voigt(pars, bounds, )
plot_fit_result(xp, reg)
plt.gca().set(xlim=(295,280))
plt.legend()

# %%
bg[1].fit['C1s']
# Out:
# <h2> Model</h2> Model(voigt, prefix='v1_') <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>21</td><td></td></tr><tr><td># data points</td><td>151</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 7142.54162</td><td></td></tr><tr><td>reduced chi-square</td><td> 48.2604163</td><td></td></tr><tr><td>Akaike info crit.</td><td> 588.338163</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 597.390002</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th><th> expression </th></tr><tr><td> v1_amplitude </td><td>  807.088592 </td><td>  7.76954380 </td><td> (0.96%) </td><td> 1325.4996819836574 </td><td>  0.00000000 </td><td>         inf </td><td> True </td><td>  </td></tr><tr><td> v1_center </td><td>  286.834952 </td><td>  0.0148
# ...
